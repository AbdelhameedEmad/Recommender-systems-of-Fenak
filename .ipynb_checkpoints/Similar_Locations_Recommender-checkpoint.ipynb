# %%
import pandas as pd

#importing the dataset
df = pd.read_csv("yelp_business.csv")

#taking the attributes that we want
data = df[["business_id","city","stars","review_count","categories"]]

#display all the imported data
df.head()
# Out:
#               business_id                        name neighborhood  \
# 0  FYWN1wneV18bWNgQjJ2GNg          "Dental by Design"          NaN
# 1  He-G7vWjzVUysIKrfNbPUQ       "Stephen Szabo Salon"          NaN
# 2  KQPW8lFf1y5BT2MxiSZ3QA     "Western Motor Vehicle"          NaN
# 3  8DShNS-LuFqpEWIp0HxijA          "Sports Authority"          NaN
# 4  PfOCPjBrlQAnz__NXj9h_w  "Brick House Tavern + Tap"          NaN
#
#                             address            city state postal_code  \
# 0        "4855 E Warner Rd, Ste B9"       Ahwatukee    AZ       85044
# 1              "3101 Washington Rd"        McMurray    PA       15317
# 2          "6025 N 27th Ave, Ste 1"         Phoenix    AZ       85017
# 3  "5000 Arizona Mills Cr, Ste 435"           Tempe    AZ       85282
# 4                    "581 Howe Ave"  Cuyahoga Falls    OH       44221
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  33.330690 -111.978599    4.0            22        1
# 1  40.291685  -80.104900    3.0            11        1
# 2  33.524903 -112.115310    1.5            18        1
# 3  33.383147 -111.964725    3.0             9        0
# 4  41.119535  -81.475690    3.5           116        1
#
#                                           categories
# 0  Dentists;General Dentistry;Health & Medical;Or...
# 1  Hair Stylists;Hair Salons;Men's Hair Salons;Bl...
# 2  Departments of Motor Vehicles;Public Services ...
# 3                            Sporting Goods;Shopping
# 4  American (New);Nightlife;Bars;Sandwiches;Ameri...

# %%
#All categories in yelp_business.csv
import pandas as pd
df = pd.read_csv("yelp_business.csv")
categoriesL = pd.unique(df.categories).tolist()
i = 0
y = []
while i < len(categoriesL):
    x = categoriesL[i].split(";")
    z = 0
    while z < len(x):
        if x[z] in y:
            z += 1
        else:
            y.append(x[z])
            z += 1
    i +=1
# i = 0
# print(len(y))
# while i < len(y):
#     print(y[i])
#     i += 1

# %%
import pandas as pd
from rake_nltk import Rake
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer

#importing the dataset
df = pd.read_csv("yelp_business.csv")

#taking the attributes that we want
data = df[["business_id","name","city","categories"]]

#filling the null values with any city
data = data.fillna("Giza")

#taking a sample of the data
data = data.sample(frac=0.01, replace=True)
print(data.name.count())

#displaying the result
data.head()
# Out:
# 1746
#                    business_id                                  name  \
# 18712   FQDoxOKH31URBSGLTYNCXg                  "Breathe Oxygen Bar"
# 117175  Fqn9kULGZll_a5qTv-Wpbg                            "My Bliss"
# 7635    M8_rmJsgE7An87k5qDww1A               "AB Charles Hobby Shop"
# 88774   ej_dVRQornawsLhK3Cp5Aw                    "Blu Lounge Salon"
# 67624   n0JifoI1yWxaBiv7VLRc4Q  "Markham Ribfest and Music Festival"
#
#               city                                         categories
# 18712    Las Vegas  Day Spas;Health & Medical;Oxygen Bars;Beauty &...
# 117175     Gilbert  Life Coach;Health & Medical;Beauty & Spas;Prof...
# 7635       McMurry                               Hobby Shops;Shopping
# 88774   Scottsdale  Beauty & Spas;Hair Stylists;Blow Dry/Out Servi...
# 67624      Markham  Arts & Entertainment;Restaurants;Barbeque;Fest...

# %%
#setting the indicies to businesses names to call the data with
data = data.set_index('name')

# instantiating and generating the count matrix
count = CountVectorizer()
count_matrix = count.fit_transform(data['categories'])

# generating the cosine similarity matrix
cosine_sim = cosine_similarity(count_matrix, count_matrix)
# print(cosine_sim)

# creating a Series for the businesses names 
# so they are associated to an ordered numerical
# list I will use in the function to match the indexes
indices = pd.Series(data.index)

# defining the function that takes in business name
# as input and returns the top 10 recommended places
def recommendations(title, cosine_sim = cosine_sim):
    
    # initializing the empty list of recommended places
    recommended_places = []
    
    # gettin the index of the place that matches the business name
    idx = indices[indices == title].index[0]

    # creating a Series with the similarity scores in descending order
    score_series = pd.Series(cosine_sim[idx]).sort_values(ascending = False)

    # getting the indexes of the 10 most similar places
    top_10_indexes = list(score_series.iloc[1:11].index)
    
    # populating the list with the names of the best 10 matching places
    for i in top_10_indexes:
        recommended_places.append(list(data.index)[i])
        
    return recommended_places

# %%
print(data.loc['"AB Charles Hobby Shop"', 'categories'])
recommendations('"AB Charles Hobby Shop"')
# Out:
# Hobby Shops;Shopping
# ['"Gamestop Store 2472"',
#  '"A & B Prospecting Supplies"',
#  '"Fine Ash Cigars"',
#  '"Pittsburgh Vape Lounge"',
#  '"Blick Art Materials"',
#  '"GoodLife Vapes"',
#  '"Comic Outlaws"',
#  '"Oh La La by Posh"',
#  '"Zest for Living"',
#  '"No Limit Smokes"']

# %%
print(data.loc['"A & B Prospecting Supplies"', 'categories'])
# Out:
# Hobby Shops;Shopping
